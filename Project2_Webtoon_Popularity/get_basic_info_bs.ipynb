# %% [markdown]
# # Get Basic Information with Beautiful Soup
# *DATE:* 2022-07-29
#
# *SUMMARY:* Get Webtoon ID, Update day, Thumbnail, Title, Author, Plot, Genre, Recommended age from the Naver Webtoon homepage.
#
# *FEATURE:* Use BeautifulSoup for scraping information. Other version would be uploaded soon.
#
# **WARNING**\
# It is based on the HTML/CSS format from July, 2022. So it may not function correctly now. For correction, check Naver Webtoon homepage's updated HTML/CSS format.

# %% [markdown]
# # Scraping information from the page

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd
import time
import requests
import os 
from urllib.request import urlretrieve 
from tqdm import tqdm_notebook
import re

# %%
idlist = []
daylist = []
imglist = [] 
titlelist = [] 
namelist = [] 
contentlist = [] 
genrelist = []
agelist = [] 
formlist = []

# %%
# From the url, get every information that classified class:title as info
url='https://comic.naver.com/webtoon/weekday.nhn'
res=requests.get(url)
soup=bs(res.text, 'html.parser')

info = soup.find_all('a', {'class':'title'})

# %%
# Get ID and Update day from info 
numID = []
href = []
dates = []

for i in info:
    href = i.attrs['href'].split('/')
    href = href[2]
    
    num = re.findall(r'\d+', href)
    numID.append(num[0])
    
    hrefday = href.split('=')
    hrefday = hrefday[2]

    dates.append(hrefday)

# Make a dataframe 
df = pd.DataFrame()
df['id']=numID
df['day']=dates

# %%
# Visualize a datafram
# If a toon updates more than twice within a week, information can be retrieved redundantly. 
# This duplication issue is addressed during the scraping process.
df
# Out:
#          id  day
# 0    758037  mon
# 1    183559  mon
# 2    648419  mon
# 3    783052  mon
# 4    602910  mon
# ..      ...  ...
# 549  776096  sun
# 550  786973  sun
# 551  798303  sun
# 552  798177  sun
# 553  798172  sun
#
# [554 rows x 2 columns]

# %%
# Scarping according to ID and Update day information
for ID, date in tqdm_notebook(iddate):
    url='https://comic.naver.com/webtoon/list?titleId='+ID+'&weekday='+date
    res = requests.get(url)
    res.raise_for_status() # Break when warn
    soup = bs(res.text, 'lxml')
    time.sleep(0.5)
    
    # Duplication processing
    if (ID in idlist): 
        daylist[idlist.index(ID)] += ',' + date
        
    else: 
        idlist.append(ID)
        daylist.append(date)

        imgpath= soup.select_one('.comicinfo > .thumb')
        imgsrc = imgpath.select_one('img').attrs.get('src')
        imglist.append(imgsrc)

        detailpath = soup.select_one('.comicinfo > .detail')
        title = detailpath.select_one('h2 > .title').text
        titlelist.append(title)

        name = detailpath.select_one('h2 > .wrt_nm').text[8:]
        namelist.append(name)
        content = detailpath.select_one('p').text
        contentlist.append(content)

        detailinfopath = soup.select_one('.comicinfo > .detail > .detail_info')
        genre = detailinfopath.select_one('.genre').text
        genrelist.append(genre)
        age = detailinfopath.select_one('.age').text
        agelist.append(age)
        
        # Get the form cut-toon using the feature that cut-toon has 'ico_cut' path
        try:
            cuttoon = detailpath.select_one('h2 > .ico_cut').txt
            form = '컷툰'
        except:
            form = '스크롤'
        formlist.append(form)
# Out:
# C:\Users\gynchoi\AppData\Local\Temp\ipykernel_11976\3660862579.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for ID, date in tqdm_notebook(iddate):
#   0%|          | 0/549 [00:00<?, ?it/s]

# %%
# Visualize a dataframe
cols = []
df = pd.DataFrame(columns=cols)

df['id'] = idlist
df['title'] = titlelist
df['name'] = namelist 
df['day'] = daylist
df['genre'] = genrelist
df['age'] = agelist
df['form'] = formlist
df['content'] = contentlist
df['imgsrc'] = imglist

df
# Out:
#          id             title       name  day     genre      age form  \
# 0    758037               참교육  채용택 / 한가람  mon   스토리, 액션  15세 이용가  스크롤
# 1    183559              신의 탑        SIU  mon  스토리, 판타지  12세 이용가  스크롤
# 2    648419           뷰티풀 군바리   설이 / 윤성원  mon  스토리, 드라마  15세 이용가  스크롤
# 3    783052           퀘스트지상주의   박태준 만화회사  mon  스토리, 드라마  15세 이용가  스크롤
# 4    602910            윈드브레이커        조용석  mon  스토리, 스포츠  12세 이용가  스크롤
# ..      ...               ...        ...  ...       ...      ...  ...
# 534  773524           거래하실래요?   99C / 백도  sun  스토리, 로맨스    전체연령가  스크롤
# 535  773067                제타         하지  sun  스토리, 스릴러  12세 이용가  스크롤
# 536  785812          구해줘, 호구!         기천  sun  스토리, 로맨스    전체연령가  스크롤
# 537  776096           짝사랑의 유서         군밤  sun  스토리, 로맨스  12세 이용가  스크롤
# 538  786973  DARK MOON: 달의 제단       HYBE  sun  스토리, 판타지  12세 이용가  스크롤
#
#                                                content  \
# 0    무너진 교권을 지키기 위해 교권보호국 소속 나화진의 참교육이 시작된다!<부활남> 채...
# 1        자신의 모든 것이었던 소녀를 쫓아 탑에 들어온 소년그리고 그런 소년을 시험하는 탑
# 2                       '여자도 군대에 간다면?'본격 여자도 군대 가는 만화!
# 3    [외모지상주의], [싸움독학], [인생존망]과 세계관을 공유하는 작품!공부, 싸움,...
# 4    혼자서 자전거를 즐겨타던 모범생 조자현.원치 않게 자전거 크루의 일에 자꾸 휘말리게...
# ..                                                 ...
# 534  새로운 사랑은 중고거래로 장만하세요(?!)남친과 헤어진 후, 추억의 물건을 중고거래...
# 535  극심한 슬럼프에 안드로이드 '제타'의 그림을 표절해버린 금세기 최고의 천재 화가 '...
# 536  세상에서 착한 게 제일 싫은 준영은 '자타공인 청정호구' 산호가 자꾸 거슬린다. 취...
# 537  민결은 단골카페 사장님의 동생인 태은을 1년동안 짝사랑 하던 중, 태은에게서 편지 ...
# 538  누구도 사랑할 수 없는 뱀파이어와 한 명밖에 사랑할 수 없는 늑대인간.리버필드 지역...
#
#                                                 imgsrc
# 0    https://shared-comic.pstatic.net/thumb/webtoon...
# 1    https://shared-comic.pstatic.net/thumb/webtoon...
# 2    https://shared-comic.pstatic.net/thumb/webtoon...
# 3    https://shared-comic.pstatic.net/thumb/webtoon...
# 4    https://shared-comic.pstatic.net/thumb/webtoon...
# ..                                                 ...
# 534  https://shared-comic.pstatic.net/thumb/webtoon...
# 535  https://shared-comic.pstatic.net/thumb/webtoon...
# 536  https://shared-comic.pstatic.net/thumb/webtoon...
# 537  https://shared-comic.pstatic.net/thumb/webtoon...
# 538  https://shared-comic.pstatic.net/thumb/webtoon...
#
# [539 rows x 9 columns]

# %%
# Visualize the toon that upload more than twice a week
df[df['id']=='793283']
# Out:
#         id   title name      day     genre      age form  \
# 89  793283  악몽의 형상  김용키  tue,sat  스토리, 스릴러  15세 이용가   컷툰
#
#                                               content  \
# 89  '타인은지옥이다', '관계의종말' 이후 9년..종우와 다은은 여전히 끔찍한 지옥 속...
#
#                                                imgsrc
# 89  https://shared-comic.pstatic.net/thumb/webtoon...

# %%
# Save as CSV format. Encoding is needed for KOREAN
df.to_csv('네이버웹툰_기본정보.csv', encoding = 'utf-8-sig')

# %% [markdown]
# # Download Thumbnail files
# With urlretrieve, download thumbnail image files from src paths.\
# Use title as a file name.

# %%
# Remove special characters
retitle = []
count=0
for i in titlelist:
    retitle.append(''.join(filter(str.isalnum, i)))
    count += 1
retitle
# Out:
# ['참교육',
#  '신의탑',
#  '뷰티풀군바리',
#  '퀘스트지상주의',
#  '윈드브레이커',
#  '호랑신랑뎐',
#  '장씨세가호위무사',
#  '소녀의세계',
#  '백수세끼',
#  '신화급귀속아이템을손에넣었다',
#  '앵무살수',
#  '잔불의기사',
#  '불청객',
#  '버림받은왕녀의은밀한침실',
#  '절대검감',
#  '똑닮은딸',
#  '리턴투플레이어',
#  '히어로메이커',
#  '아쫌참으세요영주님',
#  '꼬리잡기',
#  '야생천사보호구역',
#  '이별후사내결혼',
#  '더블클릭',
#  '결혼생활그림일기',
#  '황제와의하룻밤',
#  '메리의불타는행복회로',
#  '순정말고순종',
#  '북부공작님을유혹하겠습니다',
#  '세번째로망스',
#  '칼가는소녀',
#  '물어보는사이',
#  '우산없는애',
#  '파운더',
#  '신군',
#  '꿈의기업',
#  '오빠집이비어서',
#  '미니어처생활백서',
#  '또다시계약부부',
#  '다시쓰는연애사',
#  '제왕빛과그림자',
#  '오늘의비너스',
#  '버그이터',
#  '입술이예쁜남자',
#  '사랑의헌옷수거함',
#  '루크비셸따라잡기',
#  '말박왕',
#  '레지나레나용서받지못한그대에게',
#  '원작은완결난지한참됐습니다만',
#  '하루의하루',
#  '경비실에서안내방송드립니다',
#  '홍천기',
#  '아마도',
#  '싸이코리벤지',
#  '최후의금빛아이',
#  '백호랑',
#  '매지컬급식암살법사',
#  '그림자신부',
#  '달로만든아이',
#  '모노마니아',
#  '파견체',
#  '왕따협상',
#  '찌질하지만로맨스는하고싶어',
#  '나만의고막남친',
#  '악녀18세공략기',
#  '모락모락왕세자님',
#  '지옥연애환담',
#  '흔들리는세계로부터',
#  '디나운스',
#  '역주행',
#  '결혼공략',
#  '사막에핀달',
#  '헬로맨스',
#  '슈퍼스타천대리',
#  '남주서치',
#  '오로지오로라',
#  '별을쫓는소년들',
#  '기사님을지켜줘',
#  '모스크바의여명',
#  '김부장',
#  '대학원탈출일지',
#  '여신강림',
#  '마루는강쥐',
#  '1을줄게',
#  '멸망이후의세계',
#  '내가키운S급들',
#  '중증외상센터골든아워',
#  '신도림',
#  '용사가돌아왔다',
#  '삼국지톡',
#  '악몽의형상',
#  '집이없어',
#  '랜덤채팅의그녀',
#  '초인의게임',
#  '하북팽가막내아들',
#  '천마는평범하게살수없다',
#  '1331',
#  '원주민공포만화',
#  '호랑이들어와요',
#  '숲속의담',
#  '위아더좀비',
#  '덴큐',
#  '윌유메리미',
#  '애옹식당',
#  '올가미',
#  '에이머',
#  '헬58',
#  '몬스터',
#  '견우와선녀',
#  '늑대처럼홀로',
#  '원수가나를유혹할때',
#  '이결혼새로고침',
#  '나타나주세요',
#  '용왕님의셰프가되었습니다',
#  '제로게임',
#  '은주의방23부',
#  '빅맨',
#  '플레이플리',
#  '택배왔습니다',
#  '연우의순정',
#  '로잘린보가트',
#  '아이즈',
#  '100',
#  '한입만',
#  '시벨롬리스트',
#  '사공은주',
#  '벽간소음',
#  '대공님실수였어요',
#  '또다른사랑',
#  '여우자매',
#  '내남친킹카만들기',
#  '열녀박씨계약결혼뎐',
#  '나의플랏메이트',
#  '너의순정나의순정',
#  '붉은이정표',
#  '달이사라진밤',
#  '짝사랑의마침표',
#  '필리아로제가시왕관의예언',
#  '태시트',
#  '풋내기들',
#  '미물',
#  '나는어디에나있다',
#  '주인님을잡아먹는방법',
#  '그녀석정복기',
#  '이븐모어',
#  '그남주와이별하는방법',
#  '프린스메이커',
#  '미신',
#  'NG불가',
#  '대신심부름을해다오',
#  '교환학생',
#  '급식러너',
#  '다꾸남',
#  '잿빛오름',
#  '하나in세인',
#  '찐종합게임동아리',
#  '마녀이야기',
#  '화산귀환',
#  '2022스크롤금지',
#  '내남편과결혼해줘',
#  '전지적독자시점',
#  '조조코믹스',
#  '헬퍼2킬베로스',
#  '비즈니스여친',
#  '튜토리얼탑의고인물',
#  '일렉시드',
#  '66666년만에환생한흑마법사',
#  '남주의첫날밤을가져버렸다',
#  '여고생드래곤',
#  '기묘한만화',
#  '엔딩후서브남을주웠다',
#  '나쁜사람',
#  '칼에취한밤을걷다',
#  '쓰레기는쓰레기통에',
#  '연놈',
#  '알뜰일기',
#  '영웅마왕악당',
#  '베스트프렌드',
#  '빌드업',
#  '세상은돈과권력',
#  '마른가지에바람처럼',
#  '고삼무쌍',
#  '물고기로살아남기',
#  '사상최강',
#  '미래의골동품가게',
#  '운명을보는회사원',
#  '판타지여동생',
#  '홀리데이',
#  '언덕위의제임스',
#  '반귀',
#  '좀간',
#  '아도나이',
#  '옆집남자친구',
#  '내가죽기로결심한것은',
#  '마녀와용의신혼일기',
#  '메모리얼',
#  '헤어지면죽음',
#  '얼굴천재',
#  '선배는나빠요',
#  '수요웹툰의나강림',
#  '하렘의남자들',
#  '로어올림푸스',
#  '괴물공작의딸',
#  '가짜동맹',
#  '범이올시다',
#  '그녀의육하원칙',
#  '더퀸즈',
#  '주부육성중',
#  '두번사는프로듀서',
#  '안미운우리들',
#  '밀행',
#  '인과관계',
#  '클로닝',
#  '잿빛도색이다',
#  '사랑과평강의온달',
#  '구사일생로맨스',
#  '재생존경쟁',
#  '그림자의밤',
#  '반짝반짝작은눈',
#  '멸종위기종인간',
#  '이별학',
#  '무용과남학생',
#  '뱀은꽃을먹는가',
#  '이짝사랑은억울하다',
#  '혁명뒤공주는',
#  '낙원의이론',
#  '구주',
#  '나의계절',
#  '하지만너는2D잖아',
#  '산의시간',
#  '해귀',
#  '수호하는너에게',
#  '오직밝은미래',
#  '필생기',
#  '프로듀스온리원',
#  '아이돌의비밀스터디',
#  '우리은하',
#  '독립일기',
#  '나노마신',
#  '연애혁명',
#  '현실퀘스트',
#  '천마육성',
#  '회귀한천재헌터의슬기로운청소생활',
#  '나혼자네크로맨서',
#  '무사만리행',
#  '누나나무서워',
#  '정글쥬스',
#  '노답소녀',
#  '베니루BAENIRU',
#  '죄송한데주인공이세요',
#  '특수청소',
#  '천재의게임방송',
#  '쿠베라',
#  '하드캐리',
#  '불편한관계',
#  '개와사람의시간',
#  '남편을죽여줘요',
#  '던전씹어먹는아티팩트',
#  '버려진나의최애를위하여',
#  '최강전설강해효',
#  '꽃만키우는데너무강함',
#  '위대한겸상',
#  '트롤트랩',
#  '별을삼킨너에게',
#  '국세청망나니',
#  '완벽한결혼의정석',
#  '오빠세끼',
#  '순정빌런',
#  '선남친후연애',
#  '가족같은XX',
#  '마왕까지한걸음',
#  '황궁에핀꽃은미쳤다',
#  '만능잡캐',
#  '만물의영장',
#  '갓트',
#  '마계인섬',
#  '안개무덤',
#  '아인슈페너',
#  '널사랑하는죽은형',
#  '네가죽기를바랄때가있었다',
#  '유월의소한',
#  '마법사랑해',
#  '두번째딸로태어났습니다',
#  '권리행사자',
#  '킬더킹',
#  '1학년9반',
#  '달의요람',
#  '부캐인생',
#  '연애의발견',
#  '온에어',
#  'THE런웨이',
#  '이상한변호사우영우',
#  '가상RPG',
#  '침묵의밤',
#  '마녀의심판은꽃이된다',
#  '해시의신루',
#  '따개비',
#  '자취방신선들',
#  '환상연가',
#  '아빠같은남자',
#  '오친애하는숙적',
#  '진짜진짜이혼해',
#  '배트맨웨인패밀리어드벤처',
#  '베어케어',
#  '이계무슨황비',
#  '시에라',
#  '로맨틱태평수산',
#  '방과후레시피',
#  '그황제가시곗바늘을되돌린사연',
#  '성스러운아이돌',
#  '나쁜마법사의꿈',
#  '카루나',
#  '돌아온여기사',
#  '온실속화초',
#  '모어라이프',
#  '혼모노트',
#  '폭탄주먹변대장',
#  '사랑하는여배우들',
#  '보물과괴물의도시',
#  '외모지상주의',
#  '갓오브하이스쿨',
#  '나혼자만렙뉴비',
#  '어쩌다보니천생연분',
#  '광마회귀',
#  '데드퀸',
#  '재혼황후',
#  '1초',
#  '개를낳았다',
#  '내과박원장',
#  '죽지않으려면',
#  '낙향문사전',
#  '세기말풋사과보습학원',
#  '서울역드루이드',
#  '역대급영지설계사',
#  '뫼신사냥꾼',
#  '말년용사',
#  '여우놀이',
#  '비밀친구',
#  '히어로킬러',
#  '구남친이내게반했다',
#  '그렇고그런바람에',
#  '더게이머',
#  '선을넘은연애',
#  '멜빈이그들에게남긴것',
#  '미혼남녀의효율적만남',
#  'AI닥터',
#  '플레이어',
#  '푸쉬오프',
#  '희란국연가',
#  '이터널포스',
#  '그들이사귀는세상',
#  '그기사가레이디로사는법',
#  '스토커의하루',
#  '킬더드래곤',
#  '상위1',
#  '후덜덜덜남극전자',
#  '드래곤의심장을가지고있습니다',
#  '스포',
#  '모텔304호',
#  '네버엔딩달링',
#  '이게아닌데',
#  '악마라고불러다오',
#  '솔트앤페퍼',
#  '백년게임',
#  '여름여자하보이',
#  '로또황녀님',
#  '골든체인지',
#  '재앙의날',
#  '아찔한전남편',
#  '트럼프',
#  '인피니티',
#  '태권보이',
#  '악몽일기',
#  '오너의리스크',
#  '달이없는나라',
#  '몽홀',
#  '로판빙의만화',
#  '주님악마가되게해주세요',
#  '리트리츠',
#  '거래',
#  '짝사랑마들렌',
#  '별빛커튼콜',
#  '합법해적파르페',
#  '빨간맛로맨스',
#  '너의키스씬',
#  '히트포인트',
#  '스치면인연스며들면사랑',
#  '팬시X팬시',
#  '킬러방퍼스트킬',
#  '호랑이형님',
#  '99강화나무몽둥이',
#  '취사병전설이되다',
#  '프리드로우',
#  '은탄',
#  '망나니소교주로환생했다',
#  '초인의시대',
#  '스터디그룹',
#  '아홉수우리들',
#  '반드시해피엔딩',
#  '나이트런',
#  '존잘주의',
#  '나태공자노력천재되다',
#  '나를바꿔줘',
#  '소공녀민트',
#  '힙한남자',
#  '남편먹는여자',
#  '대충캠퍼스로맨스임',
#  '아사',
#  '작전명순정',
#  '탑코너',
#  '폭군남편과이혼하겠습니다',
#  '미나이퀄',
#  '태백튜토리얼맨',
#  '좀비파이트',
#  '키스식스센스',
#  '다비아찔하게흐르는',
#  '용사참수인',
#  '이계진입리로디드',
#  '물위의우리',
#  '홍시는날좋아해',
#  '최면학교',
#  '완벽한부부는없다',
#  '팬인데왜요',
#  '엑스애쉬',
#  '광해의연인',
#  '공유몽',
#  '묘령의황자',
#  '남편을만렙으로키우려합니다',
#  '마법사가죽음을맞이하는방법',
#  '메트로헌터',
#  '최강부캐',
#  '저무는해시린눈',
#  '은둔코인',
#  '같은학교친구',
#  '소년검사',
#  '숨겨진성녀',
#  '지구식구원자전형',
#  '배달의신',
#  '안녕이바다씨',
#  '왕년엔용사님',
#  '팔려온신부',
#  '아가사',
#  '전생연분',
#  '적월의나라',
#  '사서고생',
#  '복수를위한결혼동맹',
#  '중매쟁이아가황녀님',
#  '모두너였다',
#  '좋은데어떡해',
#  '일상이무너졌다',
#  '도사가온',
#  '더나우',
#  '주욱같은하루',
#  '키스의여왕',
#  '나를길들여봐차비서',
#  '스트릿워크아웃',
#  '보고있지',
#  '밤을깨우는마법',
#  '이건그냥연애이야기',
#  '아침을지나밤으로',
#  '좋아해아니싫어해',
#  '실버쥬얼',
#  '7FATESCHAKHO',
#  '보듬보듬',
#  '지옥급식',
#  '싸움독학',
#  '투신전생기',
#  '입학용병',
#  '약한영웅',
#  '이번생도잘부탁해',
#  '사형소년',
#  '일타강사백사부',
#  '수희0tngmlek0',
#  '존망코인',
#  '천하제일인',
#  '별이삼샵',
#  '소녀재판',
#  '아카데미에위장취업당했다',
#  '무서운게딱좋아',
#  '내일',
#  '오로지너를이기고싶어',
#  '곱게키웠더니짐승',
#  '경비배두만',
#  '판사이한영',
#  '테러대부활',
#  '시월드가내게집착한다',
#  '마법스크롤상인지오',
#  '어느날갑자기서울은',
#  '경자전성시대',
#  '홍의관의은밀한비밀',
#  '킬링킬러',
#  '동생친구',
#  '폰투스극야2',
#  '마섹남마술하는섹시한남자',
#  '위닝샷',
#  '장풍전',
#  '고백취소도되나',
#  '하렘에서살아남기',
#  '학교정벌',
#  '천치전능',
#  '생존로그',
#  '결혼까지망상했어',
#  '후궁스캔들',
#  '황제에게하트를심어주세요',
#  '랑데뷰',
#  '마왕의고백',
#  '장미같은소리',
#  '몸이바뀌는사정',
#  '나의작은서점',
#  '위험한남편을길들이는법',
#  '전설의화석',
#  '여우애담',
#  '돌아이',
#  '데빌샷',
#  '예쁜사나이',
#  '생존고백',
#  '보스의노골적취향',
#  '굿리스너',
#  '사람은고쳐쓰는게아니야',
#  '아마도굿모닝',
#  '오른눈이보는세계',
#  '블러드리벤저',
#  '보통아이',
#  '조선여우스캔들',
#  '신이담긴아이',
#  '라커오프너',
#  '샤인스타',
#  '당신의여자가되고싶어요',
#  '6월의라벤더',
#  '혀로만난사이',
#  '철수와영희이야기',
#  '마도',
#  '밀실마피아게임',
#  '독신마법사기숙아파트',
#  '패션쇼',
#  '거래하실래요',
#  '제타',
#  '구해줘호구',
#  '짝사랑의유서',
#  'DARKMOON달의제단']

# %%
# Save thumbnail with src path
fileNo = 0
for i in tqdm_notebook(range(len(imglist))):
    urlretrieve(imglist[i], "C:/Users/gynchoi/Trap/image/"+retitle[i]+".jpg")
    fileNo += 1
    time.sleep(1)
# Out:
# C:\Users\gynchoi\AppData\Local\Temp\ipykernel_11976\1455101036.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(imglist))):
#   0%|          | 0/539 [00:00<?, ?it/s]
